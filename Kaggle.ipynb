# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
# Out:
# /home/ubantu/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubantu/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv("/home/ubantu/Documents/DS/comptkaggle/compt1/train.csv")

# %%
data.head(100)
# Out:
#     Unnamed: 0  Age          WorkClass  fnlwgt      Education  EducationNum  \
# 0            0   39          State-gov   77516      Bachelors            13
# 1            1   50   Self-emp-not-inc   83311      Bachelors            13
# 2            2   38            Private  215646        HS-grad             9
# 3            3   53            Private  234721           11th             7
# 4            4   28            Private  338409      Bachelors            13
# 5            5   37            Private  284582        Masters            14
# 6            6   49            Private  160187            9th             5
# 7            7   52   Self-emp-not-inc  209642        HS-grad             9
# 8            8   31            Private   45781        Masters            14
# 9            9   42            Private  159449      Bachelors            13
# 10          10   37            Private  280464   Some-college            10
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0         int64
# Age                int64
# WorkClass         object
# fnlwgt             int64
# Education         object
# EducationNum       int64
# Marital-Status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# CapitalGain        int64
# CapitalLoss        int64
# HoursPerWeek       int64
# NativeCountry     object
# Target             int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
# Unnamed: 0        32561 non-null int64
# Age               32561 non-null int64
# WorkClass         32561 non-null object
# fnlwgt            32561 non-null int64
# Education         32561 non-null object
# EducationNum      32561 non-null int64
# Marital-Status    32561 non-null object
# Occupation        32561 non-null object
# Relationship      32561 non-null object
# Race              32561 non-null object
# Sex               32561 non-null object
# CapitalGain       32561 non-null int64
# CapitalLoss       32561 non-null int64
# HoursPerWeek      32561 non-null int64
# NativeCountry     32561 non-null object
# Target            32561 non-null int64
# dtypes: int64(8), object(8)
# memory usage: 4.0+ MB

# %%
col=data.columns
#data.head()
print(col)
# Out:
# Index(['Unnamed: 0', 'Age', 'WorkClass', 'fnlwgt', 'Education', 'EducationNum',
#        'Marital-Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'CapitalGain', 'CapitalLoss', 'HoursPerWeek', 'NativeCountry',
#        'Target'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))

sns.heatmap(data.corr(),annot=True)

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

# %%
le = LabelEncoder()

# %%
data['Marital-Status']=le.fit_transform(data['Marital-Status'])
data['WorkClass']=le.fit_transform(data['WorkClass'])
data['Relationship']=le.fit_transform(data['Relationship'])
data['Race']=le.fit_transform(data['Race'])
data['Sex']=le.fit_transform(data['Sex'])
data['NativeCountry']=le.fit_transform(data['NativeCountry'])
data['Occupation']=le.fit_transform(data['Occupation'])

# %%
data.pop("Education")
data.pop("Unnamed: 0")
data.pop("fnlwgt")
data.pop("Relationship")
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        5
# 5        5
# 6        1
# 7        0
# 8        1
# 9        0
# 10       0
# 11       0
# 12       3
# 13       1
# 14       0
# 15       0
# 16       3
# 17       4
# 18       0
# 19       4
# 20       0
# 21       4
# 22       0
# 23       0
# 24       4
# 25       0
# 26       3
# 27       0
# 28       1
# 29       0
#         ..
# 32531    1
# 32532    0
# 32533    0
# 32534    4
# 32535    3
# 32536    1
# 32537    1
# 32538    4
# 32539    0
# 32540    3
# 32541    1
# 32542    0
# 32543    4
# 32544    1
# 32545    5
# 32546    1
# 32547    0
# 32548    1
# 32549    2
# 32550    0
# 32551    0
# 32552    0
# 32553    1
# 32554    0
# 32555    1
# 32556    5
# 32557    0
# 32558    4
# 32559    3
# 32560    5
# Name: Relationship, Length: 32561, dtype: int64

# %%
#sns.pairplot(data)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True)

# %%
data.head(50)
# Out:
#     Age  WorkClass  EducationNum  Marital-Status  Occupation  Race  Sex  \
# 0    39          7            13               4           1     4    1
# 1    50          6            13               2           4     4    1
# 2    38          4             9               0           6     4    1
# 3    53          4             7               2           6     2    1
# 4    28          4            13               2          10     2    0
# 5    37          4            14               2           4     4    0
# 6    49          4             5               3           8     2    0
# 7    52          6             9               2           4     4    1
# 8    31          4            14               4          10     4    0
# 9    42          4            13               2           4     4    1
# 10   37          4            10               2           4     2    1
# 11   30          7            13               2          10     1    1
# ...

# %%
data.head()
# Out:
#    Age  WorkClass  EducationNum  Marital-Status  Occupation  Race  Sex  \
# 0   39          7            13               4           1     4    1
# 1   50          6            13               2           4     4    1
# 2   38          4             9               0           6     4    1
# 3   53          4             7               2           6     2    1
# 4   28          4            13               2          10     2    0
#
#    CapitalGain  CapitalLoss  HoursPerWeek  NativeCountry  Target
# 0         2174            0            40             39       0
# 1            0            0            13             39       0
# 2            0            0            40             39       0
# 3            0            0            40             39       0
# 4            0            0            40              5       0

# %%
data['NativeCountry']=data['NativeCountry'].replace(0,np.nan)
data['WorkClass']=data['WorkClass'].replace(0,np.nan)
data['Occupation']=data['Occupation'].replace(0,np.nan)

# %%
data.head(50)
# Out:
#     Age  WorkClass  EducationNum  Marital-Status  Occupation  Race  Sex  \
# 0    39        7.0            13               4         1.0     4    1
# 1    50        6.0            13               2         4.0     4    1
# 2    38        4.0             9               0         6.0     4    1
# 3    53        4.0             7               2         6.0     2    1
# 4    28        4.0            13               2        10.0     2    0
# 5    37        4.0            14               2         4.0     4    0
# 6    49        4.0             5               3         8.0     2    0
# 7    52        6.0             9               2         4.0     4    1
# 8    31        4.0            14               4        10.0     4    0
# 9    42        4.0            13               2         4.0     4    1
# 10   37        4.0            10               2         4.0     2    1
# 11   30        7.0            13               2        10.0     1    1
# ...

# %%
data=data.fillna(data.mean())

# %%
data.head(50)
print(data.mode())
# Out:
#    Age  WorkClass  EducationNum  Marital-Status  Occupation  Race  Sex  \
# 0   36        4.0             9               2        10.0     4    1
#
#    CapitalGain  CapitalLoss  HoursPerWeek  NativeCountry  Target
# 0            0            0            40           39.0       0

# %%
x=data.drop(labels='Target',axis=1)

# %%
y=data['Target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
predict=knn.predict(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# /home/ubantu/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(x_test)

# %%
x_train.head()
# Out:
#        Age  WorkClass  EducationNum  Marital-Status  Occupation  Race  Sex  \
# 27585   51   4.000000            14               2    4.000000     4    1
# 18010   46   4.100081             9               3    6.967088     1    1
# 22472   25   4.000000            13               4   10.000000     2    0
# 4585    27   4.000000            12               4    8.000000     4    1
# 11191   47   2.000000            14               2   10.000000     4    1
#
#        CapitalGain  CapitalLoss  HoursPerWeek  NativeCountry
# 27585            0            0            50           39.0
# 18010            0            0            40           30.0
# 22472            0            0            55           39.0
# 4585             0            0            40           39.0
# 11191         7688            0            45           39.0

# %%
from sklearn.metrics import accuracy_score,roc_auc_score

# %%
roc_auc_score(y_test,predict)
# Out:
# 0.7702458875204549

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8411501954215522

# %%
test = pd.read_csv("/home/ubantu/Documents/DS/comptkaggle/compt1/testing.csv")

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

# %%
le = LabelEncoder()


test['Marital-Status']=le.fit_transform(test['Marital-Status'])
test['WorkClass']=le.fit_transform(test['WorkClass'])
test['Relationship']=le.fit_transform(test['Relationship'])
test['Race']=le.fit_transform(test['Race'])
test['Sex']=le.fit_transform(test['Sex'])
test['NativeCountry']=le.fit_transform(test['NativeCountry'])
test['Occupation']=le.fit_transform(test['Occupation'])


test.pop("Education")
test.pop("Relationship")
test.pop("Unnamed: 0")
test.pop("fnlwgt")

plt.figure(figsize=(20,20))
sns.heatmap(test.corr(),annot=True)

# %%
test['NativeCountry']=test['NativeCountry'].replace(0,np.nan)
test['WorkClass']=test['WorkClass'].replace(0,np.nan)
test['Occupation']=test['Occupation'].replace(0,np.nan)


test=test.fillna(test.mean())

#knn.fit(x_train,y_train)
predict=knn.predict(test)

# %%
#roc_auc_score(y_test,predict)

# %%
#accuracy_score(y_test,predict)

# %%
sub = pd.read_csv("/home/ubantu/Documents/DS/comptkaggle/compt1/submission.csv")

# %%
predict.shape
# Out:
# (16281,)

# %%
sub['Target']=predict

# %%
sub.to_csv('abc.csv',index=False)
